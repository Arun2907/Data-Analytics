# %% [markdown]
# In a particular college there are student coming from diffrent background and have diffrent knowledge base.so here we are analysing student performance using python libraries

# %% [raw]
# # our dataset has following attributes

# %% [raw]
# #Gender
# #race/ethnicity
# #parental level of education
# #lunch category
# #test preparation course
# #math score
# #reading score
# #writing score

# %% [raw]
# # importing the dependencies

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# load the dataset

df=pd.read_excel('StudentsPerformance.xls')
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
# getting sample from dataset

df.sample()
# Out:
#      gender race/ethnicity parental level of education     lunch  \
# 804  female        group C                some college  standard
#
#     test preparation course  math score  reading score  writing score
# 804                    none          73             76             78

# %%
# getting information of data

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race/ethnicity               1000 non-null   object
#  2   parental level of education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test preparation course      1000 non-null   object
#  5   math score                   1000 non-null   int64
#  6   reading score                1000 non-null   int64
#  7   writing score                1000 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB

# %%
# desciptive statistics of dataset

df.describe()
# Out:
#        math score  reading score  writing score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %%
#categorical columns

df.select_dtypes('object').nunique()
# Out:
# gender                         2
# race/ethnicity                 5
# parental level of education    6
# lunch                          2
# test preparation course        2
# dtype: int64

# %%
# checking missing values

df.isnull().sum()
# Out:
# gender                         0
# race/ethnicity                 0
# parental level of education    0
# lunch                          0
# test preparation course        0
# math score                     0
# reading score                  0
# writing score                  0
# dtype: int64

# %%
df['percentage']=((df['math score']+df['reading score']+df['writing score'])*1/3).round(2)
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# ...

# %%
sns.pairplot(data=df,hue='gender')

# %%
import dabl

# %%
dabl.plot(df,target_col='math score')
# Out:
# Target looks like regression
# C:\Users\srigu\anaconda3\lib\site-packages\dabl\plot\utils.py:374: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(
# C:\Users\srigu\anaconda3\lib\site-packages\dabl\plot\utils.py:374: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(
# C:\Users\srigu\anaconda3\lib\site-packages\dabl\plot\utils.py:374: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(
# C:\Users\srigu\anaconda3\lib\site-packages\dabl\plot\utils.py:374: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(
# C:\Users\srigu\anaconda3\lib\site-packages\dabl\plot\utils.py:374: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(
# [array([[<AxesSubplot:title={'center':'F=5.40E+03'}, xlabel='percentage', ylabel='math score'>,
# ...

# %%
dabl.plot(df,target_col='reading score')
# Out:
# Target looks like regression
# C:\Users\srigu\anaconda3\lib\site-packages\dabl\plot\utils.py:374: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(
# C:\Users\srigu\anaconda3\lib\site-packages\dabl\plot\utils.py:374: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(
# C:\Users\srigu\anaconda3\lib\site-packages\dabl\plot\utils.py:374: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(
# C:\Users\srigu\anaconda3\lib\site-packages\dabl\plot\utils.py:374: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(
# C:\Users\srigu\anaconda3\lib\site-packages\dabl\plot\utils.py:374: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(
# [array([[<AxesSubplot:title={'center':'F=1.61E+04'}, xlabel='percentage', ylabel='reading score'>,
# ...

# %%
dabl.plot(df,target_col='writing score')
# Out:
# Target looks like regression
# C:\Users\srigu\anaconda3\lib\site-packages\dabl\plot\utils.py:374: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(
# C:\Users\srigu\anaconda3\lib\site-packages\dabl\plot\utils.py:374: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(
# C:\Users\srigu\anaconda3\lib\site-packages\dabl\plot\utils.py:374: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(
# C:\Users\srigu\anaconda3\lib\site-packages\dabl\plot\utils.py:374: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(
# C:\Users\srigu\anaconda3\lib\site-packages\dabl\plot\utils.py:374: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(
# [array([[<AxesSubplot:title={'center':'F=1.38E+04'}, xlabel='percentage', ylabel='writing score'>,
# ...

# %%
dabl.plot(df,target_col='percentage')
# Out:
# Target looks like regression
# C:\Users\srigu\anaconda3\lib\site-packages\dabl\plot\utils.py:374: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(
# C:\Users\srigu\anaconda3\lib\site-packages\dabl\plot\utils.py:374: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(
# C:\Users\srigu\anaconda3\lib\site-packages\dabl\plot\utils.py:374: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(
# C:\Users\srigu\anaconda3\lib\site-packages\dabl\plot\utils.py:374: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(
# C:\Users\srigu\anaconda3\lib\site-packages\dabl\plot\utils.py:374: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(
# [array([[<AxesSubplot:title={'center':'F=1.61E+04'}, xlabel='reading score', ylabel='percentage'>,
# ...

# %%
df[['lunch','gender','math score','writing score','reading score']].groupby(['lunch','gender']).agg('median')
# Out:
#                      math score  writing score  reading score
# lunch        gender
# free/reduced female        57.0           68.0           67.0
#              male          62.0           59.0           61.0
# standard     female        67.0           76.0           75.0
#              male          72.0           67.0           67.5

# %%
df[['test preparation course','gender','math score','writing score','reading score']].groupby(['test preparation course','gender']).agg('median')
# Out:
#                                 math score  writing score  reading score
# test preparation course gender
# completed               female          67             79             78
#                         male            73             70             71
# none                    female          62             70             71
#                         male            67             60             63

# %%
df[['race/ethnicity','gender','math score','writing score','reading score']].groupby(['race/ethnicity','gender']).agg('median')
# Out:
#                        math score  writing score  reading score
# race/ethnicity gender
# group A        female        57.0           67.0           67.5
#                male          63.0           60.0           61.0
# group B        female        62.0           71.5           71.5
#                male          65.0           60.0           62.0
# group C        female        63.0           74.0           73.0
#                male          68.0           62.0           66.0
# group D        female        65.0           76.0           74.0
#                male          71.0           67.0           68.0
# group E        female        71.0           76.0           76.0
#                male          78.0           70.0           73.0

# %%
df[['parental level of education','math score','writing score','reading score']].groupby(['parental level of education']).agg('median')
# Out:
#                              math score  writing score  reading score
# parental level of education
# associate's degree                 67.0           70.5           72.5
# bachelor's degree                  68.0           74.0           73.0
# high school                        63.0           64.0           66.0
# master's degree                    73.0           75.0           76.0
# some college                       67.5           70.0           70.5
# some high school                   65.0           66.0           67.0

# %%
sns.distplot(df['percentage'],color='green')
plt.title('Comparison of percentage scored by all the student')
# Out:
# C:\Users\srigu\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0.5, 1.0, 'Comparison of percentage scored by all the student')

# %%
def grades(p):
    
    if(p>=90):
        return 'o'
    if(p>=80):
        return 'A'
    if(p>=70):
        return 'B'
    if(p>=60):
        return 'C'
    if(p>=50):
        return 'D'
    if(p>=40):
        return 'E'
    else:
        return 'F'
    
df['status']=df.apply(lambda x:grades(x['percentage']),axis=1)

# %%
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# ...

# %%
df.value_counts('status')
# Out:
# status
# B    261
# C    256
# D    182
# A    146
# E     73
# o     52
# F     30
# dtype: int64

# %% [markdown]
# 90-100---->o
# 80-90----->A
# 70-80----->B
# 60-70----->C
# 50-60----->D
# 40-50----->E
# BELOW 40---->F

# %%
sns.countplot(df['status'])
# Out:
# C:\Users\srigu\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='status', ylabel='count'>

# %%
df.corr()
# Out:
#                math score  reading score  writing score  percentage
# math score       1.000000       0.817580       0.802642    0.918744
# reading score    0.817580       1.000000       0.954598    0.970331
# writing score    0.802642       0.954598       1.000000    0.965669
# percentage       0.918744       0.970331       0.965669    1.000000

# %%
sns.heatmap(df.corr())
# Out:
# <AxesSubplot:>
